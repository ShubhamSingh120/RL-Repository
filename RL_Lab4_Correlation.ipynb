# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamSingh120/RL-Repository/blob/main/RL_Lab4_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x = np.random.randint(0,50,500)

# %%
x
# Out:
# array([15, 40, 36,  8, 37, 30, 21, 41, 44, 36, 12, 30, 41, 18, 11, 22, 48,
#        27,  8, 45,  3, 35, 48, 15, 46, 44, 43, 44,  7, 27, 38, 34, 37, 44,
#        29,  8, 32,  5,  8,  0, 25, 27, 15, 16,  4,  3, 27, 17,  2,  9,  9,
#        17, 10, 45, 33, 20, 10, 40,  0, 44, 27, 23,  4, 11, 32, 47, 20, 48,
#         4, 21, 10, 26, 33,  8,  7, 16, 49, 39, 37, 10, 10,  3, 22, 29, 41,
#         6, 30, 19, 17, 46, 15,  0, 49, 19, 46, 41, 29,  0,  1,  6, 35, 48,
#         0, 32, 32, 41, 26, 43, 27, 16, 47, 12, 39, 19,  0, 21,  4, 38, 40,
#        36,  5, 25,  3, 15,  8, 28, 34,  1, 39, 31, 19, 25, 19, 22, 34, 11,
#        32, 49, 29, 32, 30,  6, 23, 20, 23, 25,  3, 48, 31, 24, 38,  8, 16,
#         7,  2, 19, 43, 43, 32, 25,  9,  3, 10, 32,  1, 33, 11, 31, 31, 14,
#        35, 49, 42, 14, 48, 38, 23, 23, 12,  4, 30,  0, 25, 38, 37, 42, 30,
#        41, 11, 27, 17,  0, 45, 32, 14, 16, 32, 18, 43, 35, 28, 36, 30, 37,
# ...

# %%
y = x + np.random.normal(0,10,500)

# %%
a = np.random.normal(0,10,10)

# %%
a
# Out:
# array([-15.60458492, -10.17125863,   9.47618685, -16.10876732,
#         -0.77486533,  -0.58636508, -15.53238297,  10.77567446,
#        -11.00839185,  -1.87167339])

# %%
y
# Out:
# array([ 16.63128758,  36.02324675,  30.10970443,  14.7772284 ,
#         26.69445482,  35.43236475,  21.36550996,  28.37133581,
#         33.61301186,  29.10779943,  19.74853267,  15.84731853,
#         43.09918998,  21.4184509 ,   1.94671495,  23.78373744,
#         60.0343398 ,  14.9222484 ,  -4.13017465,  49.36635611,
#          1.13174127,  37.60445373,  47.924632  ,  14.16209144,
#         49.52633019,  68.03987861,  38.89704854,  19.07828015,
#          1.07858383,   5.49123452,  38.82993531,  47.94513201,
#         41.37386947,  47.75904241,  30.16748151,  12.50294139,
#         13.0663525 ,   4.16943762,  16.29071775,  -2.42223283,
#         28.08884497,  21.03329884,  28.08843147,   8.08641687,
#         18.21104107,   4.73432201,  22.25478512,  -0.43431336,
#          7.19572723,   9.47146625,  17.3282359 ,   5.48638797,
#         10.86823095,  46.82090214,  25.48743041,  20.26219408,
#          4.80766078,  36.60134797,  11.01545596,  36.41254645,
# ...

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.83972955],
#        [0.83972955, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
x = np.random.randint(0, 50, 1000)

y = 100 - x + np.random.normal(0, 5, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94094382],
#        [-0.94094382,  1.        ]])

# %%
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
x = np.random.randint(0,50,1000)

# %%
y = np.random.randint(0,50,1000)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.03328295],
#        [0.03328295, 1.        ]])

# %%
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000)
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 1000)
df['d'] = np.random.normal(0, 5, 1000)

# %%
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.808717 -0.940814 -0.033275
# b  0.808717  1.000000 -0.759284 -0.049699
# c -0.940814 -0.759284  1.000000  0.011200
# d -0.033275 -0.049699  0.011200  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
